# %% [markdown]
# **CREDIT CARD FRAUD DETECTION**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# **DATA COLLECTION AND PROCESSIONG**

# %%
creditdata=pd.read_csv('/content/creditcard.csv')

# %%
creditdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditdata.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 29794  35633  0.786689 -0.691214 -0.329291  0.149435  0.714779  1.949061
# 29795  35633  0.800996 -2.159993  0.008378 -1.081828 -1.768799 -0.445016
# 29796  35633  1.115726 -0.472602  0.983034  0.294673 -1.218768 -0.341755
# 29797  35634  1.239103 -1.000617  0.843324 -0.560021 -1.400343 -0.151696
# 29798  35634  1.374193 -0.720679  0.891375 -0.541402 -1.700000       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 29794 -0.136906  0.474172  0.206173  ... -0.165285 -0.793473 -0.030110
# 29795 -0.571165 -0.162429 -1.785636  ...  0.016930 -0.350492 -0.234889
# 29796 -0.667340  0.171155  0.805427  ...  0.104463  0.366801 -0.073219
# 29797 -1.026058 -0.001637 -0.131138  ...  0.325954  0.855203 -0.245683
# 29798       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
creditdata.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 29794  35633  0.786689 -0.691214 -0.329291  0.149435  0.714779  1.949061
# 29795  35633  0.800996 -2.159993  0.008378 -1.081828 -1.768799 -0.445016
# 29796  35633  1.115726 -0.472602  0.983034  0.294673 -1.218768 -0.341755
# 29797  35634  1.239103 -1.000617  0.843324 -0.560021 -1.400343 -0.151696
# 29798  35634  1.374193 -0.720679  0.891375 -0.541402 -1.700000       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 29794 -0.136906  0.474172  0.206173  ... -0.165285 -0.793473 -0.030110
# 29795 -0.571165 -0.162429 -1.785636  ...  0.016930 -0.350492 -0.234889
# 29796 -0.667340  0.171155  0.805427  ...  0.104463  0.366801 -0.073219
# 29797 -1.026058 -0.001637 -0.131138  ...  0.325954  0.855203 -0.245683
# 29798       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
creditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29799 entries, 0 to 29798
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    29799 non-null  int64
#  1   V1      29799 non-null  float64
#  2   V2      29799 non-null  float64
#  3   V3      29799 non-null  float64
#  4   V4      29799 non-null  float64
#  5   V5      29799 non-null  float64
#  6   V6      29798 non-null  float64
#  7   V7      29798 non-null  float64
#  8   V8      29798 non-null  float64
#  9   V9      29798 non-null  float64
#  10  V10     29798 non-null  float64
#  11  V11     29798 non-null  float64
#  12  V12     29798 non-null  float64
#  13  V13     29798 non-null  float64
#  14  V14     29798 non-null  float64
#  15  V15     29798 non-null  float64
#  16  V16     29798 non-null  float64
#  17  V17     29798 non-null  float64
#  18  V18     29798 non-null  float64
#  19  V19     29798 non-null  float64
# ...

# %%
creditdata.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
creditdata['Class'].value_counts()
# Out:
# Class
# 0.0    29704
# 1.0       94
# Name: count, dtype: int64

# %%
positive=creditdata[creditdata.Class==0]
fraud=creditdata[creditdata.Class==1]

# %%
print(positive.shape)
print(fraud.shape)
# Out:
# (29704, 31)
# (94, 31)

# %%
positive.Amount.describe()
# Out:
# count    29704.000000
# mean        79.570030
# std        221.991154
# min          0.000000
# 25%          6.637500
# 50%         20.000000
# 75%         70.652500
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      94.000000
# mean       95.590000
# std       257.920621
# min         0.000000
# 25%         1.000000
# 50%         1.050000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
creditdata.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    21422.566422 -0.184395  0.106639   0.759413  0.194690 -0.186422
# 1.0    19007.702128 -8.099702  6.084984 -11.565958  6.014185 -5.681925
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.096790 -0.096841  0.018203  0.361273  ...  0.044000 -0.035795
# 1.0   -2.370349 -7.912202  4.043743 -2.891421  ...  0.679513  0.573983
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.122933 -0.041017  0.010051  0.131937  0.022275  0.009773  0.004475
# 1.0   -0.380899 -0.338752 -0.258204  0.352443  0.183181  0.830627  0.101053
#
#          Amount
# Class
# 0.0    79.57003
# 1.0    95.59000
#
# [2 rows x 30 columns]

# %%
positive_sample=positive.sample(n=492)

# %%
new_dataset=pd.concat([positive_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 2271    1816 -0.716465  1.452204  1.771555  2.502482  0.336278  1.046207
# 18445  29509  1.009333 -0.026853  1.563249  2.806653 -0.755242  1.040413
# 12571  22023  1.288211 -0.250372  0.704737 -0.713194 -0.690291 -0.288290
# 10387  16724 -1.227680 -0.092312  2.700566  1.740657  0.085494  0.900491
# 11099  19178  1.185023 -0.393969  0.991069 -0.552476 -1.051898 -0.328668
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 2271   0.229896  0.520514 -1.372524  ... -0.129199 -0.238354  0.069672
# 18445 -0.835851  0.520255  0.303875  ...  0.105262  0.621239 -0.078511
# 12571 -0.627972 -0.098027  3.073961  ... -0.204532 -0.082947 -0.144788
# 10387  0.611806 -0.201129  2.260376  ... -0.667874 -0.570081  0.471931
# 11099 -0.798928  0.080773  3.258005  ... -0.140532  0.052021  0.008491
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
# 29687  35585 -2.019001  1.491270  0.005222  0.817253  0.973252 -0.639268
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 27362 -0.123372  0.223122 -0.673598  ... -0.159387 -0.305154  0.053620
# 27627 -2.275789  0.675229 -2.042416  ...  0.469212 -0.144363 -0.317981
# 27738 -2.206056 -2.282725 -0.292885  ...  1.774460 -0.771390  0.065727
# 27749 -5.479117  1.189472 -3.908206  ...  1.192694  0.090356 -0.341881
# 29687 -0.974073 -3.146929 -0.003159  ...  2.839596 -1.185443 -0.142812
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     94
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    22370.676829 -0.191411 -0.003375   0.949155  0.152787 -0.232182
# 1.0    19007.702128 -8.099702  6.084984 -11.565958  6.014185 -5.681925
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.047862 -0.076080  0.085046  0.459417  ...  0.013473 -0.053839
# 1.0   -2.370349 -7.912202  4.043743 -2.891421  ...  0.679513  0.573983
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.003244 -0.066734  0.038743  0.132654  0.049380  0.004966 -0.016659
# 1.0   -0.380899 -0.338752 -0.258204  0.352443  0.183181  0.830627  0.101053
#
#           Amount
# Class
# 0.0    75.803252
# 1.0    95.590000
#
# [2 rows x 30 columns]

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 2271    1816 -0.716465  1.452204  1.771555  2.502482  0.336278  1.046207
# 18445  29509  1.009333 -0.026853  1.563249  2.806653 -0.755242  1.040413
# 12571  22023  1.288211 -0.250372  0.704737 -0.713194 -0.690291 -0.288290
# 10387  16724 -1.227680 -0.092312  2.700566  1.740657  0.085494  0.900491
# 11099  19178  1.185023 -0.393969  0.991069 -0.552476 -1.051898 -0.328668
# ...      ...       ...       ...       ...       ...       ...       ...
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
# 29687  35585 -2.019001  1.491270  0.005222  0.817253  0.973252 -0.639268
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape ,x_train.shape,x_test.shape)
# Out:
# (586, 30) (468, 30) (118, 30)

# %%
model=LogisticRegression(max_iter=1000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
LogisticRegression(max_iter=1000)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(y_train,x_train_prediction)

# %%
print('Accuracy score of test data:', training_data_accuracy)
# Out:
# Accuracy score of test data: 0.9914529914529915

# %% [markdown]
# **ACCURACY ON TEST MODEL**

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(y_test,x_test_prediction)

# %%
print('Accuracy score of test data:', test_data_accuracy)
# Out:
# Accuracy score of test data: 0.9830508474576272
